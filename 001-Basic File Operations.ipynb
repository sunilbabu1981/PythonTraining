# %%
print("Hello World")
# Out:
# Hello World

# %%
ordersPath = "/data/retail_db/orders/part-00000"
ordersFile = open(filePath)
ordersData = ordersFile.read()

# %%
type(ordersData)
# Out:
# str

# %%
print(ordersData)
print(len(ordersData))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
ordersList = ordersData.splitlines()

# %%
print(type(ordersList))
# Out:
# <class 'list'>

# %%
ordersList[:10]
# Out:
# ['1,2013-07-25 00:00:00.0,11599,CLOSED',
#  '2,2013-07-25 00:00:00.0,256,PENDING_PAYMENT',
#  '3,2013-07-25 00:00:00.0,12111,COMPLETE',
#  '4,2013-07-25 00:00:00.0,8827,CLOSED',
#  '5,2013-07-25 00:00:00.0,11318,COMPLETE',
#  '6,2013-07-25 00:00:00.0,7130,COMPLETE',
#  '7,2013-07-25 00:00:00.0,4530,COMPLETE',
#  '8,2013-07-25 00:00:00.0,2911,PROCESSING',
#  '9,2013-07-25 00:00:00.0,5657,PENDING_PAYMENT',
#  '10,2013-07-25 00:00:00.0,5648,PENDING_PAYMENT']

# %%
len(ordersList)
# Out:
# 68883

# %%
def readData(path):
    file = open(path)
    data = file.read()
    datalist = data.splitlines()
    return datalist

# %%
readData(ordersPath)
# Out:
# ['1,2013-07-25 00:00:00.0,11599,CLOSED',
#  '2,2013-07-25 00:00:00.0,256,PENDING_PAYMENT',
#  '3,2013-07-25 00:00:00.0,12111,COMPLETE',
#  '4,2013-07-25 00:00:00.0,8827,CLOSED',
#  '5,2013-07-25 00:00:00.0,11318,COMPLETE',
#  '6,2013-07-25 00:00:00.0,7130,COMPLETE',
#  '7,2013-07-25 00:00:00.0,4530,COMPLETE',
#  '8,2013-07-25 00:00:00.0,2911,PROCESSING',
#  '9,2013-07-25 00:00:00.0,5657,PENDING_PAYMENT',
#  '10,2013-07-25 00:00:00.0,5648,PENDING_PAYMENT',
#  '11,2013-07-25 00:00:00.0,918,PAYMENT_REVIEW',
#  '12,2013-07-25 00:00:00.0,1837,CLOSED',
#  '13,2013-07-25 00:00:00.0,9149,PENDING_PAYMENT',
#  '14,2013-07-25 00:00:00.0,9842,PROCESSING',
#  '15,2013-07-25 00:00:00.0,2568,COMPLETE',
#  '16,2013-07-25 00:00:00.0,7276,PENDING_PAYMENT',
#  '17,2013-07-25 00:00:00.0,2667,COMPLETE',
#  '18,2013-07-25 00:00:00.0,1205,CLOSED',
#  '19,2013-07-25 00:00:00.0,9488,PENDING_PAYMENT',
#  '20,2013-07-25 00:00:00.0,9198,PROCESSING',
#  '21,2013-07-25 00:00:00.0,2711,PENDING',
# ...

# %%
orderItems = "/data/retail_db/order_items/part-00000"
readData(orderItems)
print(len(readData(orderItems)))
# Out:
# 172198

# %%
t = ()

# %%
type(t)
# Out:
# tuple

# %%
t = (1,'sunil','425 Jayne Ellen Way','CLOSED')
print(type(t))
# Out:
# <class 'tuple'>

# %%
t[0]
# Out:
# 1

# %%
t[1:3]
# Out:
# ('sunil', '425 Jayne Ellen Way')

# %%
t[:]
# Out:
# (1, 'sunil', '425 Jayne Ellen Way', 'CLOSED')

# %%
t[3]
# Out:
# 'CLOSED'
